# %% [markdown]
# <a href="https://colab.research.google.com/github/ImArsar/Seminars/blob/master/Regresion_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lectura de datos
dat <- read.csv("grillos.csv")

# %%
head(dat)
# Out:
#   chirridos temp
# 1 20.0      88.6
# 2 16.0      71.6
# 3 19.8      93.3
# 4 18.4      84.3
# 5 17.1      80.6
# 6 15.5      75.2

# %%
mean(dat$chirridos)

# %%
min(dat$chirridos)

# %%
max(dat$chirridos)

# %%
summary(dat$chirridos)

# %%
summary(dat$temp)

# %%
hist(dat$chirridos)
# Out:
# Plot with title “Histogram of dat$chirridos”

# %%
hist(dat$temp)
# Out:
# Plot with title “Histogram of dat$temp”

# %%
#gráfica de disperción
#scatter pot
plot(dat$temp, dat$chirridos)

# %%
cor(dat$temp, dat$chirridos)

# %%
r <- lm(chirridos ~ temp, data = dat)

# %%
summary (r)
# Out:
# Call:
# lm(formula = chirridos ~ temp, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.56009 -0.57930  0.03129  0.59020  1.53259
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.30914    3.10858  -0.099 0.922300
# temp         0.21192    0.03871   5.475 0.000107 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9715 on 13 degrees of freedom
# Multiple R-squared:  0.6975,	Adjusted R-squared:  0.6742
# F-statistic: 29.97 on 1 and 13 DF,  p-value: 0.0001067

# %% [markdown]
# $chirridos= -0.31+0.21temp$

# %%
plot(dat$temp, dat$chirridos)
abline (r,col="green")
# Out:
# plot without title
