# %% [markdown]
# <a href="https://colab.research.google.com/github/ImArsar/Seminars/blob/master/Regresion_Lineal(BODY/BRAIN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lectura de datos
dat <- read.csv("brain_weight.csv")

# %%
head(dat)
# Out:
#   brain_weight body_weight
# 1   3.385       44.5
# 2   0.480       15.5
# 3   1.350        8.1
# 4 465.000      423.0
# 5  36.330      119.5
# 6  27.660      115.0

# %%
summary(dat$brain_weight)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    0.005    0.600    3.342  198.790   48.203 6654.000

# %%
summary(dat$body_weight)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.14    4.25   17.25  283.13  166.00 5712.00

# %%
hist(dat$brain_weight)
# Out:
# Plot with title “Histogram of dat$brain_weight”

# %%
hist(dat$body_weight)
# Out:
# Plot with title “Histogram of dat$body_weight”

# %%
#gráfica de disperción
#scatter pot
plot(dat$body_weight, dat$brain_weight)
# Out:
# plot without title

# %%
cor(dat$body_weight, dat$brain_weight)
# Out:
# [1] 0.9341638

# %%
r <- lm(brain_weight ~ body_weight, data = dat)

# %%
summary (r)
# Out:
# Call:
# lm(formula = brain_weight ~ body_weight, data = dat)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1552.25    -8.00    47.36    55.10  1553.42
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -56.85555   42.97805  -1.323    0.191
# body_weight   0.90291    0.04453  20.278   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 323.5 on 60 degrees of freedom
# Multiple R-squared:  0.8727,	Adjusted R-squared:  0.8705
# F-statistic: 411.2 on 1 and 60 DF,  p-value: < 2.2e-16

# %% [markdown]
# $brain$_$weight= -56.9+.90Body-weight$

# %%
plot(dat$body_weight, dat$brain_weight)
abline (r,col="green")
# Out:
# plot without title
