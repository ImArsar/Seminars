# %% [markdown]
# <a href="https://colab.research.google.com/github/ImArsar/Seminars/blob/master/Regresion_Lineal(tiempo-calificaciones).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lectura de datos
dat <- read.csv("exam_dat.csv")

# %%
head(dat[ ,1-2])
# Out:
#   marks times
# 1 49    2860
# 2 49    2063
# 3 70    2013
# 4 55    2000
# 5 52    1420
# 6 55    1934

# %%
mean(dat$marks)
# Out:
# [1] 54.52985

# %%
min(dat$marks)
# Out:
# [1] 28

# %%
max(dat$marks)
# Out:
# [1] 73

# %%
summary(dat$marks)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   28.00   48.25   55.00   54.53   62.00   73.00

# %%
summary(dat$times)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1068    1512    1756    1824    2013    3813

# %%
hist(dat$marks)
# Out:
# Plot with title “Histogram of dat$marks”

# %%
hist(dat$times)
# Out:
# Plot with title “Histogram of dat$times”

# %%
#gráfica de disperción
#scatter pot
plot(dat$times, dat$marks)
# Out:
# plot without title

# %%
cor(dat$times, dat$marks)
# Out:
# [1] -0.05713813

# %%
r <- lm(marks ~ times, data = dat)

# %%
summary (r)
# Out:
# Call:
# lm(formula = marks ~ times, data = dat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -27.029  -5.720   0.352   7.341  18.660
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 56.733267   3.457018  16.411   <2e-16 ***
# times       -0.001208   0.001837  -0.658    0.512
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.835 on 132 degrees of freedom
# Multiple R-squared:  0.003265,	Adjusted R-squared:  -0.004286
# F-statistic: 0.4324 on 1 and 132 DF,  p-value: 0.512

# %% [markdown]
# $marks= 56.7+0.001times$

# %%
plot(dat$times, dat$marks)
abline (r,col="green")
# Out:
# plot without title
